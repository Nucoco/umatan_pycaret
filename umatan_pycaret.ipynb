# %%
# !pip install pycaret
# Out:
# ...
#   Using cached numpy-1.19.5-cp38-cp38-win_amd64.whl (13.3 MB)
# ...
# WARNING: Error parsing requirements for numpy: [Errno 2] No such file or directory: 'c:\\users\\ytonomura\\anaconda3\\envs\\ai\\lib\\site-packages\\numpy-1.21.0.dist-info\\METADATA'
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: 'c:\\users\\ytonomura\\anaconda3\\envs\\ai\\lib\\site-packages\\numpy-1.21.0.dist-info\\RECORD'
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.0

# %%
from pycaret.datasets import get_data
boston = get_data("boston")
# Out:
#       crim    zn  indus  chas    nox  ...  tax  ptratio   black  lstat  medv
# 0  0.00632  18.0   2.31     0  0.538  ...  296     15.3  396.90   4.98  24.0
# 1  0.02731   0.0   7.07     0  0.469  ...  242     17.8  396.90   9.14  21.6
# 2  0.02729   0.0   7.07     0  0.469  ...  242     17.8  392.83   4.03  34.7
# 3  0.03237   0.0   2.18     0  0.458  ...  222     18.7  394.63   2.94  33.4
# 4  0.06905   0.0   2.18     0  0.458  ...  222     18.7  396.90   5.33  36.2
#
# [5 rows x 14 columns]

# %%
# regression
from pycaret.regression import *
# preprocessing
prepro = setup(boston, target="medv", train_size=0.7)
# Out:
# <style  type="text/css" >
# #T_a2723_row42_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_a2723_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a2723_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_a2723_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_a2723_row0_col1" class="data row0 col1" >4493</td>
#             </tr>
#             <tr>
#                         <th id="T_a2723_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_a2723_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_a2723_row1_col1" class="data row1 col1" >medv</td>
#             </tr>
#             <tr>
# ...

# %%
# model building by various methods
compare_models()
# Out:
# <style  type="text/css" >
#     #T_b738f_ th {
#           text-align: left;
# ...

# %%
# create model by lightgbm after doing cross validation
lightgbm = create_model('lightgbm')
# Out:
# <style  type="text/css" >
# #T_83ef2_row10_col0,#T_83ef2_row10_col1,#T_83ef2_row10_col2,#T_83ef2_row10_col3,#T_83ef2_row10_col4,#T_83ef2_row10_col5{
#             background:  yellow;
#         }</style><table id="T_83ef2_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_83ef2_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_83ef2_row0_col0" class="data row0 col0" >2.9476</td>
#                         <td id="T_83ef2_row0_col1" class="data row0 col1" >20.5003</td>
# ...

# %%
# output each indicator to predict data
predict_model = predict_model(lightgbm)
# Out:
# <style  type="text/css" >
# </style><table id="T_7935b_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7935b_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_7935b_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#                         <td id="T_7935b_row0_col1" class="data row0 col1" >2.6914</td>
#                         <td id="T_7935b_row0_col2" class="data row0 col2" >16.3753</td>
# ...
